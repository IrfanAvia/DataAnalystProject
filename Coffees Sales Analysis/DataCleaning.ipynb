# %%
import pandas as pd
import io
import numpy as np
import seaborn as sns

sns.set_context('notebook')
sns.set_style('darkgrid')
sns.set_palette('Spectral')


import os
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 500)  # Mengatur jumlah maksimum kolom yang ditampilkan pada DataFrame agar dapat menampilkan hingga 500 kolom.
pd.set_option('display.max_rows', 500)     # Mengatur jumlah maksimum baris yang ditampilkan pada DataFrame agar dapat menampilkan hingga 500 baris.
df

# %%
df = pd.read_csv('index.csv')
df
# Out:
#            date                 datetime cash_type                 card  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1    2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2    2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3    2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4    2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ..          ...                      ...       ...                  ...
# 891  2024-06-29  2024-06-29 21:27:22.449      card  ANON-0000-0000-0009
# 892  2024-06-30  2024-06-30 10:28:09.842      card  ANON-0000-0000-0336
# 893  2024-06-30  2024-06-30 13:05:50.620      card  ANON-0000-0000-0337
# 894  2024-06-30  2024-06-30 16:54:41.679      card  ANON-0000-0000-0009
# 895  2024-06-30  2024-06-30 21:04:09.746      card  ANON-0000-0000-0097
#
#      money          coffee_name
# 0    38.70                Latte
# 1    38.70        Hot Chocolate
# ...

# %%
df.isnull().any()
# Out:
# date           False
# datetime       False
# cash_type      False
# card            True
# money          False
# coffee_name    False
# dtype: bool

# %%
df.info
# Out:
# <bound method DataFrame.info of            date                 datetime cash_type                 card  \
# 0    2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1    2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2    2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3    2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4    2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ..          ...                      ...       ...                  ...
# 891  2024-06-29  2024-06-29 21:27:22.449      card  ANON-0000-0000-0009
# 892  2024-06-30  2024-06-30 10:28:09.842      card  ANON-0000-0000-0336
# 893  2024-06-30  2024-06-30 13:05:50.620      card  ANON-0000-0000-0337
# 894  2024-06-30  2024-06-30 16:54:41.679      card  ANON-0000-0000-0009
# 895  2024-06-30  2024-06-30 21:04:09.746      card  ANON-0000-0000-0097
#
#      money          coffee_name
# 0    38.70                Latte
# ...

# %%
df[df['card'].isna()==1]
# Out:
#            date                 datetime cash_type card  money  \
# 12   2024-03-02  2024-03-02 10:30:35.668      cash  NaN   40.0
# 18   2024-03-03  2024-03-03 10:10:43.981      cash  NaN   40.0
# 41   2024-03-06  2024-03-06 12:30:27.089      cash  NaN   35.0
# 46   2024-03-07  2024-03-07 10:08:58.945      cash  NaN   40.0
# 49   2024-03-07  2024-03-07 11:25:43.977      cash  NaN   40.0
# 60   2024-03-09  2024-03-09 11:49:37.292      cash  NaN   40.0
# 74   2024-03-10  2024-03-10 07:44:18.538      cash  NaN   30.0
# 75   2024-03-10  2024-03-10 07:45:29.441      cash  NaN   35.0
# 76   2024-03-10  2024-03-10 10:06:02.960      cash  NaN   40.0
# 78   2024-03-10  2024-03-10 17:51:03.048      cash  NaN   35.0
# 81   2024-03-11  2024-03-11 10:18:46.724      cash  NaN   40.0
# 82   2024-03-11  2024-03-11 11:24:15.022      cash  NaN   40.0
# 83   2024-03-11  2024-03-11 11:24:51.565      cash  NaN   30.0
# 84   2024-03-11  2024-03-11 11:26:44.221      cash  NaN   30.0
# ...

# %%
df['card'] = df['card'].fillna(0)
df.isna().any()
# Out:
# date           False
# datetime       False
# cash_type      False
# card           False
# money          False
# coffee_name    False
# dtype: bool

# %%
df.dtypes
# Out:
# date            object
# datetime        object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df = df.astype({'datetime': 'datetime64[ns]'})

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# date           0
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# dtype: int64

# %%
df.dtypes
# Out:
# date            object
# datetime        object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object

# %%
df0 = df.groupby(['date']).agg(money_sum=('money', 'count'), money_count=('money', 'sum')).reset_index()
df0 = df0.rename(columns={'money_count': 'total_revenue',
                        'money_sum' : 'transaction_count'})
df0
# Out:
#            date  transaction_count  total_revenue
# 0    2024-03-01                 11         396.30
# 1    2024-03-02                  7         228.10
# 2    2024-03-03                 10         349.10
# 3    2024-03-04                  4         135.20
# 4    2024-03-05                  9         338.50
# 5    2024-03-06                  5         170.20
# 6    2024-03-07                  6         220.10
# 7    2024-03-08                  8         265.50
# 8    2024-03-09                 14         479.40
# 9    2024-03-10                  7         231.60
# 10   2024-03-11                  8         275.20
# 11   2024-03-12                  7         228.10
# 12   2024-03-13                  9         256.20
# 13   2024-03-14                 12         397.10
# 14   2024-03-15                  3         107.60
# 15   2024-03-16                  6         183.20
# 16   2024-03-17                  2          68.90
# 17   2024-03-18                  4         115.60
# ...
